# %% [markdown]
# #operator

# %%
a=17
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 22
# 12
# 85
# 3.4
# 3
# 2
# 1419857

# %% [markdown]
# # logical operators

# %%
a=True
b=False
print(a and b)
print(a or b)
print(not b)
# Out:
# False
# True
# True

# %% [markdown]
# # Identify operators

# %%
a=10
b=5
c=a
print(c is a)
print(a is not b)
# Out:
# True
# True

# %% [markdown]
# # Ternary operator

# %%
min=a if a<b else b
print(min)
# Out:
# 5

# %% [markdown]
# # Members operators

# %%
x=24
y=20
list1=[10,20,30,40]
if y not in list1:
    print("X not in list")
    if y in list:
        print("y is in list")

# %% [markdown]
# # questional (find output)

# %%
print(100/10*10)
print(5-2+3)
print(5-(2+3))
print(2**3**2)
# Out:
# 100.0
# 6
# 0
# 512
